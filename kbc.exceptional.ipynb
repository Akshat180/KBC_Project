# %%
import random
def fiftyfifty(c):

    d= {
        "que1: What is the capital of India?": ["New Delhi", "Mumbai", "Kolkata", "Chennai"],
        "que2: What is the largest country in the world?": ["Russia", "China", "Usa", "India"],
        "que3: Who was the first man to step on the moon?": ["Neil Armstrong", "Buzz Aldrin", "Yuri Gagarin", "Alan Shepard"],
        "que4: What is the currency of Japan?": ["Yen", "Dollar", "Euro", "Pound"],
        "que5: What is the highest mountain in the world?": ["Mount Everest", "K2", "Kangchenjunga", "Lhotse"]
    }

    do = {"answer1":'New Delhi',"answer2" :'China', "ans3":'Neil Armstrong', "ans4":'Yen', "ans5":'K2'}


    x= list(d.keys())
    y= list(do.keys())

    
    

    print(x[c])
    input1 = do[y[c]]
    input2= random.choice(d[x[c]])

    if input1==input2:
        input2= random.choice(do[y[c]])

    else:
        print(input1,"or",input2)
        ans=input("answer: ").title()
        if ans==input1:
            print('answer')
            
            
        else:
            print("wrong")

# %%
d= {
    "que1: What is the capital of India?": ["New Delhi", "Mumbai", "Kolkata", "Chennai"],
    "que2: What is the largest country in the world?": ["Russia", "China", "Usa", "India"],
    "que3: Who was the first man to step on the moon?": ["Neil Armstrong", "Buzz Aldrin", "Yuri Gagarin", "Alan Shepard"],
    "que4: What is the currency of Japan?": ["Yen", "Dollar", "Euro", "Pound"],
    "que5: What is the highest mountain in the world?": ["Mount Everest", "K2", "Kangchenjunga", "Lhotse"]
}

do = ['New Delhi', 'China', 'Neil Armstrong', 'Yen', 'K2']

def kbc():
    print('Welcome to kbc')
    x= list(d.keys())
    y=list(d.values())
    c=0
    p=5000
    while 1:
        print()
        print(x[c])
        print(d[x[c]])
        try:
            print('''you want to answer or want lifeline
            for answer press 1
            for lifeline press 2''')
            num=int(input("option: "))
            if num==1:
                n=input(" answer:").title()
                i = d[x[c]].index(n)
            elif num==2:
                print('''press 1 to choose lifeline''')
                num2=int(input("num2:"))
                if num2==1:     
                    fiftyfifty(c)
                    print("your prize money is",p) 
                    p+=p
                    pass
                else:
                    print("none")
        except:
            print('')
            print('invalid answer try again')
            break
        else:    
            if d[x[c]][i] == do[c]:
                print('Your answer is correct')
                print("your prize money is",p) 
                p+=p
                c+=1
            else:
                print('Answer incorrect')
                p-=p
                print("your prize money is",p)
                break
        finally:
            print("ty")
                
    
kbc()
# Out:
# Welcome to kbc
#
# que1: What is the capital of India?
# ['New Delhi', 'Mumbai', 'Kolkata', 'Chennai']
# you want to answer or want lifeline
#             for answer press 1
#             for lifeline press 2
# option: 2
# press 1 to choose lifeline
# num2:1
# que1: What is the capital of India?
# New Delhi or Chennai
# answer: new delhi
# answer
# your prize money is 5000
# ty
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 58
#      54         finally:
#      55             print("ty")
# ---> 58 kbc()
#
# Cell In[7], line 44, in kbc()
#      42     break
#      43 else:
# ---> 44     if d[x[c]][i] == do[c]:
#      45         print('Your answer is correct')
#      46         print("your prize money is",p)
#
# UnboundLocalError: cannot access local variable 'i' where it is not associated with a value
